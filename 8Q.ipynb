# %%
class NQueens:
    def __init__(self, n):
        self.n = n
        self.board = [[0] * n for _ in range(n)]
        self.solutions = []

    def solve(self):
        self.backtrack(0)
        return self.solutions

    def backtrack(self, col):
        if col == self.n:
            solution = []
            for row in self.board:
                queen_col = row.index(1)
                solution.append(queen_col)
            self.solutions.append(solution)
            return

        for row in range(self.n):
            if self.is_safe(row, col):
                self.board[row][col] = 1
                self.backtrack(col + 1)
                self.board[row][col] = 0

    def is_safe(self, row, col):
        for i in range(col):
            if self.board[row][i] == 1:
                return False

        i, j = row, col
        while i >= 0 and j >= 0:
            if self.board[i][j] == 1:
                return False
            i -= 1
            j -= 1

        i, j = row, col
        while i < self.n and j >= 0:
            if self.board[i][j] == 1:
                return False
            i += 1
            j -= 1

        return True


# Get user input for the number of queens
n = int(input("Enter the number of queens: "))
queens = NQueens(n)
solutions = queens.solve()

print(f"Number of solutions for {n}-queens problem: {len(solutions)}")
for i, solution in enumerate(solutions):
    print(f"Solution {i + 1}: {solution}")
# Out:
# Enter the number of queens:  8
# Number of solutions for 8-queens problem: 92
# Solution 1: [0, 6, 4, 7, 1, 3, 5, 2]
# Solution 2: [0, 6, 3, 5, 7, 1, 4, 2]
# Solution 3: [0, 5, 7, 2, 6, 3, 1, 4]
# Solution 4: [0, 4, 7, 5, 2, 6, 1, 3]
# Solution 5: [5, 0, 4, 1, 7, 2, 6, 3]
# Solution 6: [3, 0, 4, 7, 1, 6, 2, 5]
# Solution 7: [4, 0, 7, 3, 1, 6, 2, 5]
# Solution 8: [2, 0, 6, 4, 7, 1, 3, 5]
# Solution 9: [4, 0, 3, 5, 7, 1, 6, 2]
# Solution 10: [6, 0, 2, 7, 5, 3, 1, 4]
# Solution 11: [4, 0, 7, 5, 2, 6, 1, 3]
# Solution 12: [3, 0, 4, 7, 5, 2, 6, 1]
# Solution 13: [1, 5, 0, 6, 3, 7, 2, 4]
# Solution 14: [4, 2, 0, 6, 1, 7, 5, 3]
# Solution 15: [7, 2, 0, 5, 1, 4, 6, 3]
# Solution 16: [3, 5, 0, 4, 1, 7, 2, 6]
# Solution 17: [4, 6, 0, 3, 1, 7, 5, 2]
# Solution 18: [5, 2, 0, 7, 3, 1, 6, 4]
# Solution 19: [4, 2, 0, 5, 7, 1, 3, 6]
# Solution 20: [5, 2, 0, 7, 4, 1, 3, 6]
# Solution 21: [3, 7, 0, 2, 5, 1, 6, 4]
# Solution 22: [7, 3, 0, 2, 5, 1, 6, 4]
# Solution 23: [3, 7, 0, 4, 6, 1, 5, 2]
# Solution 24: [3, 6, 0, 7, 4, 1, 5, 2]
# Solution 25: [5, 3, 0, 4, 7, 1, 6, 2]
# Solution 26: [5, 2, 0, 6, 4, 7, 1, 3]
# Solution 27: [6, 2, 0, 5, 7, 4, 1, 3]
# Solution 28: [4, 6, 0, 2, 7, 5, 3, 1]
# Solution 29: [1, 4, 6, 0, 2, 7, 5, 3]
# Solution 30: [1, 7, 5, 0, 2, 4, 6, 3]
# Solution 31: [5, 1, 6, 0, 2, 4, 7, 3]
# Solution 32: [6, 1, 3, 0, 7, 4, 2, 5]
# Solution 33: [7, 1, 3, 0, 6, 4, 2, 5]
# Solution 34: [4, 1, 7, 0, 3, 6, 2, 5]
# Solution 35: [5, 1, 6, 0, 3, 7, 4, 2]
# Solution 36: [4, 1, 5, 0, 6, 3, 7, 2]
# Solution 37: [2, 4, 6, 0, 3, 1, 7, 5]
# Solution 38: [5, 3, 6, 0, 7, 1, 4, 2]
# Solution 39: [4, 7, 3, 0, 6, 1, 5, 2]
# Solution 40: [2, 5, 7, 0, 4, 6, 1, 3]
# Solution 41: [6, 4, 2, 0, 5, 7, 1, 3]
# Solution 42: [5, 3, 6, 0, 2, 4, 1, 7]
# Solution 43: [4, 7, 3, 0, 2, 5, 1, 6]
# Solution 44: [2, 5, 3, 0, 7, 4, 6, 1]
# Solution 45: [2, 5, 7, 0, 3, 6, 4, 1]
# Solution 46: [4, 6, 3, 0, 2, 7, 5, 1]
# Solution 47: [1, 5, 7, 2, 0, 3, 6, 4]
# Solution 48: [1, 4, 6, 3, 0, 7, 5, 2]
# Solution 49: [1, 6, 4, 7, 0, 3, 5, 2]
# Solution 50: [6, 1, 5, 2, 0, 3, 7, 4]
# Solution 51: [7, 1, 4, 2, 0, 6, 3, 5]
# Solution 52: [3, 1, 7, 5, 0, 2, 4, 6]
# Solution 53: [3, 1, 6, 4, 0, 7, 5, 2]
# Solution 54: [2, 5, 1, 6, 0, 3, 7, 4]
# Solution 55: [2, 4, 1, 7, 0, 6, 3, 5]
# Solution 56: [5, 7, 1, 3, 0, 6, 4, 2]
# Solution 57: [2, 7, 3, 6, 0, 5, 1, 4]
# Solution 58: [2, 4, 7, 3, 0, 6, 1, 5]
# Solution 59: [5, 2, 6, 3, 0, 7, 1, 4]
# Solution 60: [5, 2, 4, 6, 0, 3, 1, 7]
# Solution 61: [5, 2, 4, 7, 0, 3, 1, 6]
# Solution 62: [3, 7, 4, 2, 0, 6, 1, 5]
# Solution 63: [3, 6, 4, 2, 0, 5, 7, 1]
# Solution 64: [3, 5, 7, 2, 0, 6, 4, 1]
# Solution 65: [1, 3, 5, 7, 2, 0, 6, 4]
# Solution 66: [3, 1, 4, 7, 5, 0, 2, 6]
# Solution 67: [3, 1, 7, 4, 6, 0, 2, 5]
# Solution 68: [2, 6, 1, 7, 4, 0, 3, 5]
# Solution 69: [2, 5, 1, 4, 7, 0, 6, 3]
# Solution 70: [2, 5, 1, 6, 4, 0, 7, 3]
# Solution 71: [4, 6, 1, 5, 2, 0, 3, 7]
# Solution 72: [4, 6, 1, 5, 2, 0, 7, 3]
# Solution 73: [6, 3, 1, 4, 7, 0, 2, 5]
# Solution 74: [6, 3, 1, 7, 5, 0, 2, 4]
# Solution 75: [4, 6, 1, 3, 7, 0, 2, 5]
# Solution 76: [2, 5, 7, 1, 3, 0, 6, 4]
# Solution 77: [6, 2, 7, 1, 4, 0, 5, 3]
# Solution 78: [3, 6, 4, 1, 5, 0, 2, 7]
# Solution 79: [3, 5, 7, 1, 6, 0, 2, 4]
# Solution 80: [4, 2, 7, 3, 6, 0, 5, 1]
# Solution 81: [1, 6, 2, 5, 7, 4, 0, 3]
# Solution 82: [3, 1, 6, 2, 5, 7, 0, 4]
# Solution 83: [4, 1, 3, 5, 7, 2, 0, 6]
# Solution 84: [2, 6, 1, 7, 5, 3, 0, 4]
# Solution 85: [5, 3, 1, 7, 4, 6, 0, 2]
# Solution 86: [5, 2, 6, 1, 3, 7, 0, 4]
# Solution 87: [5, 2, 6, 1, 7, 4, 0, 3]
# Solution 88: [3, 6, 2, 7, 1, 4, 0, 5]
# Solution 89: [3, 1, 6, 2, 5, 7, 4, 0]
# Solution 90: [4, 1, 3, 6, 2, 7, 5, 0]
# Solution 91: [2, 4, 1, 7, 5, 3, 6, 0]
# Solution 92: [2, 5, 3, 1, 7, 4, 6, 0]
